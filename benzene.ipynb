# %%
import numpy as np

# %%
# correlation energy mHa #
hf = -230.721819131
# shci = -864.2
# dmrg = -862.8(7)
# ccsdtq = -862.4
# mbe_fci = -863.03

# afqmc_pt2 = -231.583586 +/- 0.000413
# afqmc_pt = -231.583582 +/- 0.000397
# afqmc/cisd = -231.583788 +/- 0.000727
afqmc_pt = (-231.583582 - hf)*1000
afqmc_pt2 = (-231.583586 - hf)*1000
afqmc_ci = (-231.583788 - hf)*1000

# afqmc_hf = −866.1(3)
# afqmc_cas = −864.3(4)
# print(shci)
# print(dmrg)
# print(ccsdtq)
# print(mbe_fci)
print(afqmc_pt)
print(afqmc_pt2)
print(afqmc_ci)
# Out:
# -861.7628690000174
# -861.7668690000073
# -861.9688690000089

# %%
ccsd_t = -0.8234537767933086 + -0.0360548104110
print(ccsd_t)
# Out:
# -0.8595085872043086

# %%
ccsdt = -231.5817 - hf
ccsdt_sq = -231.5826 - hf
ccsdt_pq = -231.5845 - hf
# fciqmc_pt = −0.5833(10)
fciqmc_pt = -231.5833 - hf
print(ccsdt*1000)
print(ccsdt_sq*1000)
print(ccsdt_pq*1000)
print(fciqmc_pt*1000)
# Out:
# -859.8808690000226
# -860.780869000024
# -862.6808690000018
# -861.4808690000189
