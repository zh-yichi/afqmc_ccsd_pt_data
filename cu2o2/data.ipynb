# %%
### cu2o2(2+) f=0 data ###
#   2S         RHF                 RCCSD              RCCSD(T)             UHF                 UCCSD             UCCSD(T)           AFQMC/UCCSD_PT2
#   0   -541.068335744317   -542.0011961215347  -542.0879099049172  -541.393165372973   -542.0475814797788  -542.081823248342   -542.082044 +/- 0.000756
#   2   -541.234922910795   -542.0343402311385  -542.0931340305071  -541.394889492515   -542.0484029416731  -542.083079335338   -542.087765 +/- 0.000646
#   4   -541.383862616938   -542.0589748938527  -542.0949143218171  -541.398025846968   -542.0600043589181  -542.095229015392   -542.096199 +/- 0.000490
#   6   -541.195733212075   -541.8426839412252  -541.8836384683008  -541.212838257862   -541.8442818937651  -541.884830989459               -

# %%
# s = 0
# Size of the correlation space:
# Number of electrons: (16, 16)
# Number of basis functions: 108
# Number of Cholesky vectors: 675
# norb: 108
# nelec: (16, 16)
#
# dt: 0.005
# n_eql: 5
# n_ene_blocks: 5
# n_sr_blocks: 5
# n_blocks: 80
# n_walkers: 200
# walker_type: uhf
# trial: uccsd_pt2_ad
# use_gpu: True
# n_exp_terms: 6
# n_prop_steps: 50
# seed: 225900
# orbital_rotation: True
# do_sr: True
# symmetry: False
# save_walkers: False
# ene0: 0.0
# free_projection: False
# n_batch: 1
# LNO: False
# orbE: 0
# maxError: 0.001

# Propagating with 200 walkers
# Equilibration sweeps:
# #   Iter  <exp(t1)>  <t2>  <e0>  <e1>  energy  Walltime
#       0  0.916092  0.000000  -219.817185   -0.598948   -542.047539  13.28
#       1  0.969927  0.197497  -233.389038   -47.533257   -542.079092  120.06
#       2  1.120081  0.273342  -269.502899   -65.796539   -542.077654  224.91
#       3  1.219154  0.337264  -293.361450   -81.171051   -542.083200  322.92
#       4  1.267708  0.369964  -305.027435   -89.061142   -542.089876  420.99
#       5  1.256046  0.345092  -302.194611   -83.074829   -542.073435  519.02
#
# Sampling sweeps:
#  Iter          energy          error           Walltime
    #  8           -542.083524     0.002851         1401.58
    # 16           -542.083238     0.001872         2185.78
    # 24           -542.082594     0.001444         2970.60
    # 32           -542.083105     0.001201         3755.72
    # 40           -542.082565     0.001053         4541.88
    # 48           -542.082202     0.000937         5330.81
    # 56           -542.081769     0.000842         6114.65
    # 64           -542.082392     0.000815         6898.46
    # 72           -542.082193     0.000756         7681.97
# Number of outliers in post: 0
# Final Results1:
# h0 = -301.44275088
# <exp(t1)> = 1.312142 +/- 0.000395
# <t2> = 0.391585 +/- 0.000329
# <e0> = -315.705231 +/- 0.094920
# <e1> = -94.264221 +/- 0.079111
# AFQMC/UCCSD_PT2 energy (covariance): -542.082044 +/- 0.000756
# remove outliers:  0
# AFQMC/UCCSD_PT2 energy (direct obs): -542.082031 +/- 0.000755
# total run time: 8367.26

# %%
# s = 2
# Size of the correlation space:
# Number of electrons: (17, 15)
# Number of basis functions: 108
# Number of Cholesky vectors: 675
# norb: 108
# nelec: (17, 15)
# dt: 0.005
# n_eql: 5
# n_ene_blocks: 5
# n_sr_blocks: 5
# n_blocks: 80
# n_walkers: 200
# walker_type: uhf
# trial: uccsd_pt2_ad
# use_gpu: True
# n_exp_terms: 6
# n_prop_steps: 50
# seed: 194496
# orbital_rotation: True
# do_sr: True
# symmetry: False
# save_walkers: False
# ene0: 0.0
# free_projection: False
# n_batch: 1
# LNO: False
# orbE: 0
# maxError: 0.001

# Propagating with 200 walkers
# Equilibration sweeps:
#   Iter  <exp(t1)>  <t2>  <e0>  <e1>  energy  Walltime
    #   0  -0.920432  -0.000000  220.857360   0.601365   -542.048403  20.37
    #   1  -0.993068  -0.198997  238.922211   47.918594   -542.077488  131.63
    #   2  -1.131214  -0.291686  272.188934   70.207680   -542.082516  240.10
    #   3  -1.211163  -0.334250  291.423126   80.465103   -542.092552  340.55
    #   4  -1.233596  -0.378017  296.859619   90.962608   -542.086624  441.02
    #   5  -1.294655  -0.409729  311.506226   98.633247   -542.092148  541.55
#
# Sampling sweeps:
#  Iter          energy          error           Walltime
    #  8           -542.087831     0.002040         1447.27
    # 16           -542.089043     0.001532         2251.52
    # 24           -542.087821     0.001271         3055.93
    # 32           -542.087467     0.001002         3865.65
    # 40           -542.087695     0.000838         4670.19
    # 48           -542.087868     0.000741         5474.46
    # 56           -542.087820     0.000746         6278.75
    # 64           -542.087633     0.000674         7082.60
    # 72           -542.087709     0.000670         7890.98
# Number of outliers in post: 0
# Final Results1:
# h0 = -301.44531234
# <exp(t1)> = -1.348436 +/- 0.000381
# <t2> = -0.449230 +/- 0.000368
# <e0> = 324.445435 +/- 0.091670
# <e1> = 108.134308 +/- 0.088529
# AFQMC/UCCSD_PT2 energy (covariance): -542.087765 +/- 0.000646
# remove outliers:  0
# AFQMC/UCCSD_PT2 energy (direct obs): -542.087646 +/- 0.000644
# total run time: 8594.56

# %%
# s = 4
# Size of the correlation space:
# Number of electrons: (18, 14)
# Number of basis functions: 108
# Number of Cholesky vectors: 675# norb: 108
# nelec: (18, 14)
# dt: 0.005
# n_eql: 5
# n_ene_blocks: 5
# n_sr_blocks: 5
# n_blocks: 80
# n_walkers: 200
# walker_type: uhf
# trial: uccsd_pt2_ad
# use_gpu: True
# n_exp_terms: 6
# n_prop_steps: 50
# seed: 568687
# orbital_rotation: True
# do_sr: True
# symmetry: False
# save_walkers: False
# ene0: 0.0
# free_projection: False
# n_batch: 1

# Propagating with 200 walkers
# Equilibration sweeps:
#   Iter  <exp(t1)>  <t2>  <e0>  <e1>  energy  Walltime
    #   0  0.868873  0.000000  -208.496011   -0.573360   -542.059984  20.35
    #   1  0.952038  0.192065  -229.078796   -46.243961   -542.088990  136.41
    #   2  1.142262  0.297294  -274.860748   -71.564995   -542.091366  249.98
    #   3  1.216552  0.350391  -292.747131   -84.339203   -542.093735  355.30
    #   4  1.245598  0.364099  -299.734985   -87.638466   -542.092972  460.56
    #   5  1.240022  0.341951  -298.359711   -82.326454   -542.087708  565.81
#
# Sampling sweeps:
#  Iter          energy          error           Walltime
    #  8           -542.096520     0.001100         1513.65
    # 16           -542.096683     0.000759         2356.10
    # 24           -542.096003     0.000666         3205.00
    # 32           -542.096331     0.000594         4053.83
    # 40           -542.095668     0.000575         4896.32
    # 48           -542.095732     0.000530         5738.77
    # 56           -542.096070     0.000538         6580.73
    # 64           -542.096021     0.000514         7422.92
    # 72           -542.095978     0.000519         8270.47
# Number of outliers in post: 0
# Final Results1:
# h0 = -301.43877476
# <exp(t1)> = 1.264415 +/- 0.000320
# <t2> = 0.383282 +/- 0.000242
# <e0> = -304.243835 +/- 0.077012
# <e1> = -92.272469 +/- 0.058253
# AFQMC/UCCSD_PT2 energy (covariance): -542.096199 +/- 0.000490
# remove outliers:  0
# AFQMC/UCCSD_PT2 energy (direct obs): -542.096130 +/- 0.000489
# total run time: 9006.86
